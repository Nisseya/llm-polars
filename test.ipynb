# %%
import os 
sorted(os.listdir("data/questions"))
# Out:
# ['questions_0.jsonl',
#  'questions_1.jsonl',
#  'questions_10.jsonl',
#  'questions_100.jsonl',
#  'questions_101.jsonl',
#  'questions_102.jsonl',
#  'questions_103.jsonl',
#  'questions_104.jsonl',
#  'questions_105.jsonl',
#  'questions_106.jsonl',
#  'questions_107.jsonl',
#  'questions_108.jsonl',
#  'questions_109.jsonl',
#  'questions_11.jsonl',
#  'questions_110.jsonl',
#  'questions_111.jsonl',
#  'questions_112.jsonl',
#  'questions_113.jsonl',
#  'questions_114.jsonl',
#  'questions_115.jsonl',
#  'questions_116.jsonl',
#  'questions_117.jsonl',
#  'questions_118.jsonl',
#  'questions_119.jsonl',
#  'questions_12.jsonl',
#  'questions_120.jsonl',
#  'questions_121.jsonl',
#  'questions_122.jsonl',
#  'questions_123.jsonl',
#  'questions_124.jsonl',
#  'questions_125.jsonl',
#  'questions_126.jsonl',
#  'questions_127.jsonl',
#  'questions_128.jsonl',
#  'questions_129.jsonl',
#  'questions_13.jsonl',
#  'questions_130.jsonl',
#  'questions_131.jsonl',
# ...

# %%
from pathlib import Path
import json
for path in os.listdir("data/questions"):
    with open(Path("data/questions",path),"r",encoding='utf-8') as f:
        line = json.loads(f.readline())
    #print(line["custom_id"])
    if "recommendation" in line["custom_id"].lower():
        print(path)
# Out:
# questions_3.jsonl
